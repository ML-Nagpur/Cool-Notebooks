# %%
# Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
from tensorflow.random import set_seed

import yfinance as yf
import os

set_seed(455)
np.random.seed(455)

# %%
df = pd.read_csv(
    "/content/Mastercard_stock_history.csv", index_col="Date", parse_dates=["Date"]
).drop(["Dividends", "Stock Splits"], axis=1)
df.head()
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2006-05-25  3.748967  4.283869  3.739664  4.279217  395343000
# 2006-05-26  4.307126  4.348058  4.103398  4.179680  103044000
# 2006-05-30  4.183400  4.184330  3.986184  4.093164   49898000
# 2006-05-31  4.125723  4.219679  4.125723  4.180608   30002000
# 2006-06-01  4.179678  4.474572  4.176887  4.419686   62344000

# %%
df = pd.read_csv(
    "/content/Mastercard_stock_history.csv", index_col="Date", parse_dates=["Date"]
).drop(["Dividends", "Stock Splits"], axis=1)
df.head()
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2006-05-25  3.748967  4.283869  3.739664  4.279217  395343000
# 2006-05-26  4.307126  4.348058  4.103398  4.179680  103044000
# 2006-05-30  4.183400  4.184330  3.986184  4.093164   49898000
# 2006-05-31  4.125723  4.219679  4.125723  4.180608   30002000
# 2006-06-01  4.179678  4.474572  4.176887  4.419686   62344000

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  3872.000000  3872.000000  3872.000000  3872.000000  3.872000e+03
# mean    104.896814   105.956054   103.769349   104.882714  1.232250e+07
# std     106.245511   107.303589   105.050064   106.168693  1.759665e+07
# min       3.748967     4.102467     3.739664     4.083861  6.411000e+05
# 25%      22.347203    22.637997    22.034458    22.300391  3.529475e+06
# 50%      70.810079    71.375896    70.224002    70.856083  5.891750e+06
# 75%     147.688448   148.645373   146.822013   147.688438  1.319775e+07
# max     392.653890   400.521479   389.747812   394.685730  3.953430e+08

# %%
df.isna().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
tstart = 2016
tend = 2020

def train_test_plot(df, tstart, tend):
    df.loc[f"{tstart}":f"{tend}", "High"].plot(figsize=(16, 4), legend=True)
    df.loc[f"{tend+1}":, "High"].plot(figsize=(16, 4), legend=True)
    plt.legend([f"Train (Before {tend+1})", f"Test ({tend+1} and beyond)"])
    plt.title("MasterCard stock price")
    plt.show()

train_test_plot(df,tstart,tend)

# %%
def train_test_split(dataset, tstart, tend):
    train = dataset.loc[f"{tstart}":f"{tend}", "High"].values
    test = dataset.loc[f"{tend+1}":, "High"].values
    return train, test
training_set, test_set = train_test_split(df, tstart, tend)

# %%
sc = MinMaxScaler(feature_range=(0, 1))
training_set = training_set.reshape(-1, 1)
training_set_scaled = sc.fit_transform(training_set)

# %%
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence) - 1:
            break
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)


n_steps = 60
features = 1
# split into samples
X_train, y_train = split_sequence(training_set_scaled, n_steps)

# %%
# Reshaping X_train for model
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1],features)

# %%
model_gru = Sequential()
model_gru.add(GRU(units=125, activation="tanh", input_shape=(n_steps, features)))
model_gru.add(Dense(units=1))
# Compiling the RNN
model_gru.compile(optimizer="RMSprop", loss="mse")

model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 125)               48000
#
#  dense (Dense)               (None, 1)                 126
#
# =================================================================
# Total params: 48126 (187.99 KB)
# Trainable params: 48126 (187.99 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_gru.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 3s 7ms/step - loss: 0.0122
# Epoch 2/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0017
# Epoch 3/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 4/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 5/50
# 38/38 [==============================] - 0s 5ms/step - loss: 9.8473e-04
# Epoch 6/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 7/50
# 38/38 [==============================] - 0s 5ms/step - loss: 6.9208e-04
# Epoch 8/50
# 38/38 [==============================] - 0s 5ms/step - loss: 8.9395e-04
# Epoch 9/50
# 38/38 [==============================] - 0s 6ms/step - loss: 7.4438e-04
# Epoch 10/50
# 38/38 [==============================] - 0s 6ms/step - loss: 8.3743e-04
# Epoch 11/50
# 38/38 [==============================] - 0s 7ms/step - loss: 6.8609e-04
# Epoch 12/50
# 38/38 [==============================] - 0s 6ms/step - loss: 6.4818e-04
# Epoch 13/50
# 38/38 [==============================] - 0s 6ms/step - loss: 6.1230e-04
# Epoch 14/50
# 38/38 [==============================] - 0s 6ms/step - loss: 6.1134e-04
# Epoch 15/50
# 38/38 [==============================] - 0s 6ms/step - loss: 5.6296e-04
# Epoch 16/50
# 38/38 [==============================] - 0s 6ms/step - loss: 6.1975e-04
# Epoch 17/50
# 38/38 [==============================] - 0s 6ms/step - loss: 5.9336e-04
# Epoch 18/50
# 38/38 [==============================] - 0s 6ms/step - loss: 5.2847e-04
# Epoch 19/50
# 38/38 [==============================] - 0s 6ms/step - loss: 5.2095e-04
# Epoch 20/50
# 38/38 [==============================] - 0s 6ms/step - loss: 5.3959e-04
# Epoch 21/50
# 38/38 [==============================] - 0s 5ms/step - loss: 5.5358e-04
# Epoch 22/50
# 38/38 [==============================] - 0s 5ms/step - loss: 5.0417e-04
# Epoch 23/50
# 38/38 [==============================] - 0s 5ms/step - loss: 4.9417e-04
# Epoch 24/50
# 38/38 [==============================] - 0s 5ms/step - loss: 5.4994e-04
# Epoch 25/50
# 38/38 [==============================] - 0s 5ms/step - loss: 5.4697e-04
# Epoch 26/50
# 38/38 [==============================] - 0s 5ms/step - loss: 4.9187e-04
# Epoch 27/50
# 38/38 [==============================] - 0s 5ms/step - loss: 4.4426e-04
# Epoch 28/50
# 38/38 [==============================] - 0s 5ms/step - loss: 4.5729e-04
# Epoch 29/50
# 38/38 [==============================] - 0s 5ms/step - loss: 4.5139e-04
# Epoch 30/50
# 38/38 [==============================] - 0s 5ms/step - loss: 4.7342e-04
# Epoch 31/50
# 38/38 [==============================] - 0s 5ms/step - loss: 4.2495e-04
# Epoch 32/50
# 38/38 [==============================] - 0s 5ms/step - loss: 4.1957e-04
# Epoch 33/50
# 38/38 [==============================] - 0s 5ms/step - loss: 4.7210e-04
# Epoch 34/50
# 38/38 [==============================] - 0s 5ms/step - loss: 4.0252e-04
# Epoch 35/50
# 38/38 [==============================] - 0s 5ms/step - loss: 4.3755e-04
# Epoch 36/50
# 38/38 [==============================] - 0s 5ms/step - loss: 4.1561e-04
# Epoch 37/50
# 38/38 [==============================] - 0s 5ms/step - loss: 4.2320e-04
# Epoch 38/50
# 38/38 [==============================] - 0s 5ms/step - loss: 4.2931e-04
# Epoch 39/50
# 38/38 [==============================] - 0s 5ms/step - loss: 3.6771e-04
# Epoch 40/50
# 38/38 [==============================] - 0s 5ms/step - loss: 4.5444e-04
# Epoch 41/50
# 38/38 [==============================] - 0s 5ms/step - loss: 3.8623e-04
# Epoch 42/50
# 38/38 [==============================] - 0s 5ms/step - loss: 3.7883e-04
# Epoch 43/50
# 38/38 [==============================] - 0s 5ms/step - loss: 4.8212e-04
# Epoch 44/50
# 38/38 [==============================] - 0s 5ms/step - loss: 3.3880e-04
# Epoch 45/50
# 38/38 [==============================] - 0s 5ms/step - loss: 3.9961e-04
# Epoch 46/50
# 38/38 [==============================] - 0s 12ms/step - loss: 3.7291e-04
# Epoch 47/50
# 38/38 [==============================] - 0s 9ms/step - loss: 3.9801e-04
# Epoch 48/50
# 38/38 [==============================] - 0s 8ms/step - loss: 3.2505e-04
# Epoch 49/50
# 38/38 [==============================] - 0s 9ms/step - loss: 4.1373e-04
# Epoch 50/50
# 38/38 [==============================] - 0s 7ms/step - loss: 3.5617e-04

# %%
dataset_total = df.loc[:,"High"]
inputs = dataset_total[len(dataset_total) - len(test_set) - n_steps :].values
inputs = inputs.reshape(-1, 1)
#scaling
inputs = sc.transform(inputs)

# Split into samples
X_test, y_test = split_sequence(inputs, n_steps)
# reshape
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], features)
#prediction
predicted_stock_price = model_gru.predict(X_test)
#inverse transform the values
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 7/7 [==============================] - 1s 5ms/step

# %%
def plot_predictions(test, predicted):
    plt.plot(test, color="gray", label="Real")
    plt.plot(predicted, color="red", label="Predicted")
    plt.title("MasterCard Stock Price Prediction")
    plt.xlabel("Time")
    plt.ylabel("MasterCard Stock Price")
    plt.legend()
    plt.show()


def return_rmse(test, predicted):
    rmse = np.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {:.2f}.".format(rmse))

# %%
GRU_predicted_stock_price = model_gru.predict(X_test)
GRU_predicted_stock_price = sc.inverse_transform(GRU_predicted_stock_price)
plot_predictions(test_set, GRU_predicted_stock_price)
# Out:
# 7/7 [==============================] - 0s 3ms/step

# %%
return_rmse(test_set,GRU_predicted_stock_price)
# Out:
# The root mean squared error is 5.91.
