# %% [markdown]
# <div style='background:#4169E1'>
#     <center style="font-size:4em;">Basics of Exploratory Data Analysis (EDA)</span></center>
# </div>

# %% [markdown]
# Exploratory data analysis (EDA) is used by data scientists to analyze and investigate data sets and summarize their main characteristics, often employing data visualization methods.
# EDA helps determine how best to manipulate data sources to get the answers you need, making it easier for data scientists to discover patterns, spot anomalies, test a hypothesis, or check assumptions.

# %% [markdown]
# # Types of exploratory data analysis
# ### 1. Univariate
# * Data being analyzed consists of just one variable.
# * Doesn’t deal with causes or relationships.
# ### 2. Multivariate
# * More than one variable.
# * Shows the relationship between variables of the data through cross-tabulation or statistics.

# %% [markdown]
# # Objective
# We will apply EDA to identify important factors for predicting placements.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd                # Used for data analysis and maipulation 
import matplotlib.pyplot as plt    # Create basic plots 
import seaborn as sns              # Create advanced statistical plots 
import numpy as np                 # Support for large, multi-dimensional arrays and matrices

# %% [markdown]
# # Loading the Dataset

# %%
df=pd.read_csv('./Placement.csv')
# link: https://www.kaggle.com/datasets/benroshan/factors-affecting-campus-placement
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# * The dataset provides information on various student attributes and their placement status.
# * It includes features such as gender, secondary and higher secondary education percentages, degree percentages, work experience, and placement status.
# * NaN or missing values are also present in the dataset.
# * There are categorical as well as numeric features.

# %% [markdown]
# # Detecting NaN values
#
# This method is used for checking all the columns (features) for any missing or 'NaN' values and displaying sum of these values
# Its useful for detecting and handling NaN values, so as to ensure the accuracy and reliability of data analysis results.

# %%
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# * Only salary has null values (total 67).
# * All other features don't have null values

# %%
df.head()
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p   hsc_b     hsc_s  degree_p  \
# 210    211      M   80.6   Others   82.0  Others  Commerce      77.6
# 211    212      M   58.0   Others   60.0  Others   Science      72.0
# 212    213      M   67.0   Others   67.0  Others  Commerce      73.0
# 213    214      F   74.0   Others   66.0  Others  Commerce      58.0
# 214    215      M   62.0  Central   58.0  Others   Science      53.0
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN

# %% [markdown]
# # Statistcial summary
#
# Applying 5 number summary along with other basic summary on all the features of the data. It includes:
# 1. Minimum
# 2. Maximum
# 3. Standard deviation
# 4. 1st quartile
# 5. 2nd quartile
# 6. 3rd quartile
# 7. Total count

# %%
df.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
# drop dataset index to reduce dimension
df=df.drop(['sl_no'],axis=1)

# %% [markdown]
# # Visualizing Data Distributions

# %% [markdown]
# ## 1. COUNTPLOT
# Countplot is used for plotting histogram of categorical variables.

# %%
sns.countplot(data=df,x=df['status'])
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %% [markdown]
# * This plot shows the distribution of genders in the dataset, giving insights into gender representation.
# * This helps to understand how many got places and how many did not, side by side.
# * More than half students got placed compared to non-placed students.

# %% [markdown]
# # Impact of gender on Placements

# %%
df['gender'].value_counts()
# Out:
# gender
# M    139
# F     76
# Name: count, dtype: int64

# %% [markdown]
# Here gender and status will be grouped according to status. this will show count of status, i.e. placed and not placed in both category (M, F).

# %%
sns.countplot(x='gender',hue='status',data=df)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# * X axis has gender: male and female.
# * Hue is used to specify what we have to count for male and female.

# %%
df1=pd.DataFrame(df.groupby(['gender','status'])['status'].count())   # the plot can be verified through this
# since there is count, all the counts of male and female that were placed and not placed is shown
df1
# Out:
#                    status
# gender status
# F      Not Placed      28
#        Placed          48
# M      Not Placed      39
#        Placed         100

# %% [markdown]
# Conclusion: male have more chances of getting placed than female

# %% [markdown]
# ## 2. DISTPLOT
# * Also called density plot, it depicts the variation in the data distribution.
# * represents the overall distribution of continuous data variables
# * below are some examples of distribution plots
#
# ![kaggle_distribution](https://media.licdn.com/dms/image/C4D12AQGD7OJI7TdH7g/article-cover_image-shrink_720_1280/0/1550076005937?e=2147483647&v=beta&t=vZ5Buk3LMeUIoZ2310ZUoZbsl_6BVOSv3wKLuR_bzDY)

# %% [markdown]
# # Impact of 10th grade on Placements

# %%
sns.distplot(df['ssc_p'])
plt.title('Distribution of SSC percentage')
plt.xlabel('SSC %')
# Out:
# Text(0.5, 0, 'SSC %')

# %% [markdown]
# * The peak of the distribution is around 60-70%, indicating that most students scored within this range.
# * The distribution is slightly right-skewed which means fewer students scored very high percentages.
# * The data ranges from around 30% to 100%, indicating a wide variation in SSC scores.
# * Majority of scores seem to fall between 50% and 80%.
# * The right skew suggests that while many students perform around average, high performers are fewer but exist.

# %% [markdown]
# ## 3. CATPLOT
# * Used for categorical plots.
# * Shows the relationship between a numerical and one or more categorical variables using one of several visual representations.

# %%
sns.catplot(y='ssc_p', x='status', data=df)
plt.xlabel('Employment Status')
plt.ylabel('SSC %')
# Out:
# Text(30.375617283950618, 0.5, 'SSC %')

# %% [markdown]
# * Students who are placed have higher SSC percentages, with most scores lying between 60% and 90%.
# * Students who are not placed have a wider range of SSC percentages, with most scores between 50% and 80%.
# * Placed students mostly have higher SSC scores compared to not placed students.
# * The spread for not placed students is slightly wider at the lower end of the SSC percentages, indicating that students with lower SSC percentages are less likely to be placed.
# * SSC % is a significant factor in determining employment placement status.
# * outliers indicates that while SSC % alone is not an important factor.

# %% [markdown]
# # Impact of Board of Education- Central/ Others on Placements

# %%
df['ssc_b'].value_counts()
# Out:
# ssc_b
# Central    116
# Others      99
# Name: count, dtype: int64

# %%
df1=pd.DataFrame(df.groupby(['ssc_b','status'])['status'].count())
df1
# Out:
#                     status
# ssc_b   status
# Central Not Placed      38
#         Placed          78
# Others  Not Placed      29
#         Placed          70

# %%
sns.countplot(x='ssc_b',hue='status',data=df)
# Out:
# <Axes: xlabel='ssc_b', ylabel='count'>

# %% [markdown]
# since there is minute difference in orange-blue in both bars, it can be concluded that ssc_b doesnt matter much in placement

# %% [markdown]
# # Impact of Board of Education- Central/Others on Placements

# %%
sns.displot(df['hsc_p'],kde=True)  
plt.title('Distribution of HSC Percentage')
plt.xlabel('HSC %')
# Out:
# Text(0.5, 9.444444444444438, 'HSC %')

# %%
sns.catplot(y='hsc_p',x='status',data=df)
plt.title('Distribution of HSC Percentage')
plt.xlabel('HSC %')
# Out:
# Text(0.5, 28.999999999999986, 'HSC %')

# %% [markdown]
# * Placed students generally have higher HSC percentages, between 60% and 90%.
# * There are a few students with HSC percentages below 50% and above 80% who are placed, which could be considered outliers or exceptions.
# * HSC % is a significant factor in determining employment placement status.

# %% [markdown]
# # Impact of Board of Education- Central/ Others on Placements

# %%
df['hsc_b'].value_counts()
# Out:
# hsc_b
# Others     131
# Central     84
# Name: count, dtype: int64

# %%
df1=pd.DataFrame(df.groupby(['hsc_b','status'])['status'].count())
df1
# Out:
#                     status
# hsc_b   status
# Central Not Placed      27
#         Placed          57
# Others  Not Placed      40
#         Placed          91

# %%
sns.countplot(x='hsc_b',hue='status',data=df)
# Out:
# <Axes: xlabel='hsc_b', ylabel='count'>

# %% [markdown]
# * Students from the 'Others' board have a higher number of placements compared to students from the 'Central' board.
# * Both 'Others' and 'Central' boards have more placed students than not placed students, but the difference is more pronounced for the 'Others' board.
# * So this is not an important feature for placements.

# %% [markdown]
# # Impact of Specialization in Higher Secondary Education on Placements

# %%
sns.countplot(x='hsc_s',hue='status',data=df)
# Out:
# <Axes: xlabel='hsc_s', ylabel='count'>

# %% [markdown]
# * Commerce and Science stream has significantly more placed students than not placed students, indicating better placement rates compared to those from the Arts stream.
# * Arts stream has low number of placed students.

# %%
sns.displot(df['hsc_s'],kde=False)     #kde shows where its more dense
plt.title('Distribution of HSC specialization Percentage')
plt.xlabel('HSC specialization %')
# Out:
# Text(0.5, 9.444444444444438, 'HSC specialization %')

# %% [markdown]
# # Impact of degree percentage on Placements

# %%
sns.displot(df['degree_p'],kde=False)
plt.title('Distribution of degree Percentage')
plt.xlabel('Degree %')
# Out:
# Text(0.5, 9.444444444444438, 'Degree %')

# %%
sns.catplot(y='degree_p',x='status',data=df)
plt.title('Distribution of Degree Percentage')
plt.xlabel('Degree %')
# Out:
# Text(0.5, 28.999999999999986, 'Degree %')

# %% [markdown]
# * Placed students generally have higher degree percentages, between 60% and 80%.
# * There is more variability in degree percentages among placed students, but they generally have higher scores compared to not placed students.
# * Students with lower degree percentages are less likely to be placed.
# * Academic performance in degree courses is a significant factor in determining employment placement status.

# %% [markdown]
# # Impact of Work experience on Placements

# %%
sns.countplot(x='workex',hue='status',data=df)
# Out:
# <Axes: xlabel='workex', ylabel='count'>

# %% [markdown]
# * Students with work experience have a higher placement rate compared to those without work experience.
# * Students with work experience are much more likely to be placed compared to those without work experience.
# * Work experience is a significant factor in determining employment placement status.

# %%
# to see how they contribute in combined manner
sns.displot(df['workex'],kde=False)
plt.title('Distribution of work experience Percentage')
plt.xlabel('work experience %')
# Out:
# Text(0.5, 9.444444444444438, 'work experience %')

# %% [markdown]
# # Impact of Employability test percentage on placements

# %%
sns.displot(df['etest_p'],kde=True)  
plt.title('Distribution of Employability test Percentage')
plt.xlabel('Employability test %')
# Out:
# Text(0.5, 9.444444444444438, 'Employability test %')

# %%
sns.catplot(y='etest_p', x='status', data=df)
plt.xlabel('Employment Status')
plt.ylabel('Employability test %')
# Out:
# Text(30.570061728395068, 0.5, 'Employability test %')

# %% [markdown]
# * Students who are placed generally have higher employability test percentages compared to those who are not placed.
# * Most placed students have employability test percentages ranging from around 60% to 100%, with a significant concentration between 70% and 90%.
# * Not placed students predominantly have percentages between 50% and 80%, with fewer students scoring above 80%.
# * positive correlation between higher employability test scores and the likelihood of being placed.
# * Employability test performance is an important factor in determining placement outcomes.

# %% [markdown]
# ## 4. BOXPLOT
# * Visualize data distribution for gaining insights and making informed decisions.
# * Box plot is a type of chart that depicts a group of numerical data through their quartiles.

# %%
sns.boxplot(x='status', y='etest_p', data=df)
plt.title('E-test Scores vs Placement Status')
plt.xlabel('Placement Status')
plt.ylabel('E-test Percentage')
plt.show()

# %% [markdown]
# * median E-test score for placed students is higher than for not placed students.
# * The IQR, which represents the middle 50% of the data, is wider for placed students, indicating a more varied range of E-test scores among those who are placed.
# * some students with lower scores also got placed.
# * The higher median and IQR for placed students highlight that higher E-test scores generally correlate with better placement outcomes.
# * The presence of some placed students with lower scores suggests that while E-test scores are an important factor, they are not the sole determinant of placement.

# %% [markdown]
# # Impact of specialisation on placements

# %%
sns.countplot(x='specialisation',hue='status',data=df)
# Out:
# <Axes: xlabel='specialisation', ylabel='count'>

# %% [markdown]
# * The Marketing and Finance (Mkt&Fin) specialization has a significantly higher number of placed students compared to the Marketing and Human Resources (Mkt&HR) specialization.
# * specializing in Marketing and Finance have a higher placement rate compared to those specializing in Marketing and Human Resources.

# %% [markdown]
# # Impact of MBA percentage on placements

# %%
sns.displot(df['mba_p'],kde=True)  
plt.title('Distribution of MBA Percentage')
plt.xlabel('MBA %')
# Out:
# Text(0.5, 9.444444444444438, 'MBA %')

# %% [markdown]
# * The majority of students cluster around the 60-65% range. This suggests that most students have similar academic performance in their MBA program.

# %%
sns.catplot(y='mba_p', x='status', data=df)
plt.xlabel('Employment Status')
plt.ylabel('MBA %')
# Out:
# Text(30.519367283950622, 0.5, 'MBA %')

# %% [markdown]
# * individuals with higher MBA percentages tend to be associated with greater job placement success.
# * However, there are also people with high MBA percentages who are not placed, suggesting that factors other than MBA percentage may influence employment status.

# %% [markdown]
# # Impact of Field of degree education on placements

# %%
sns.countplot(x='degree_t',hue='status',data=df)
# Out:
# <Axes: xlabel='degree_t', ylabel='count'>

# %% [markdown]
# * The "Comm&Mgmt" category has the highest number of individuals who are placed, significantly outnumbering those not placed in the same category.
# * The "Sci&Tech" category shows more individuals placed than not placed, but the difference is not as pronounced as in "Comm&Mgmt".
# * The "Others" category has the lowest count of individuals, with a slightly higher count of placed individuals compared to not placed.
# * Overall, individuals from the "Comm&Mgmt" field have the highest placement rate compared to "Sci&Tech" and "Others".

# %% [markdown]
# ## 5. PAIRPLOT
# Used for visualization of relationship between each pair of variables in a dataset.

# %%
sns.pairplot(data=df[['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'status']],hue="status",diag_kind='hist')

# %%
# drop all unwanted columns that dont contribute much as we explored above
df.drop(['ssc_b','hsc_b','hsc_s','degree_t','salary','mba_p','etest_p'], axis=1, inplace=True)

# %% [markdown]
# # Feature mapping

# %%
df["gender"]=df.gender.map({"M":0,"F":1})
df["workex"]=df.workex.map({"No":0,"Yes":1})
df["status"]=df.status.map({"Not Placed":0,"Placed":1})
df["specialisation"]=df.specialisation.map({"Mkt&HR":0,"Mkt&Fin":1})

# %%
df.columns
# Out:
# Index(['gender', 'ssc_p', 'hsc_p', 'degree_p', 'workex', 'specialisation',
#        'status'],
#       dtype='object')

# %%
# final dataset to work on
df.head()
# Out:
#    gender  ssc_p  hsc_p  degree_p  workex  specialisation  status
# 0       0  67.00  91.00     58.00       0               0       1
# 1       0  79.33  78.33     77.48       1               1       1
# 2       0  65.00  68.00     64.00       0               1       1
# 3       0  56.00  52.00     52.00       0               0       0
# 4       0  85.80  73.60     73.30       0               1       1

# %% [markdown]
# # Therefore the final list of most important features for placements is
# ## 1. gender
# ## 2. ssc_p
# ## 3. hsc_p
# ## 4. degree_p
# ## 5. workex
# ## 6. specialisation
# ## 7. status
